# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("GreedyComparison0.8.txt", sep = ",")
df = pd.DataFrame(df)
df.columns = ["onlineBarista","physicalBarista", "numCustomer", "alpha", "noReGreedy", "reGreedy", "allQueue","allLine"]


df['allLine'] = df['allLine'].str.strip(']').astype(float)
df['onlineBarista'] = df['onlineBarista'].str.strip('[').astype(float)


pd.to_numeric(df['onlineBarista'])
pd.to_numeric(df['physicalBarista'])


for i in range(1, 5):
    df_plot = df[df['onlineBarista'] == i]
    df_plot = df_plot[df_plot['physicalBarista'] == 5-i]
    print("df_plot dataframe is below")
    print(df_plot)
       
    plt.plot(df_plot['numCustomer'], df_plot['reGreedy']/df_plot['numCustomer'], label = "Greedy with Reallocation")
    plt.plot(df_plot['numCustomer'], df_plot['noReGreedy']/df_plot['numCustomer'], label = "Greedy with no Reallocation")
    plt.plot(df_plot['numCustomer'], df_plot['allQueue']/df_plot['numCustomer'],  label = "All queue with Reallocation")
    plt.plot(df_plot['numCustomer'], df_plot['allLine']/df_plot['numCustomer'], label = "All line with Reallocation")

    plt.xlabel("Number of customers")
    plt.ylabel("Average cost")
    plt.legend(loc="upper left", fontsize = "5")

    plt.title("Num of online baristas: " + str(i) + ", Num of physical baristas:" + str(5-i))
   
    plt.tight_layout()

    plt.savefig("C:\\Users\\Kiet Nguyen\\Documents\\UofR\\SUMMER_2024\\EmpiricalResults\\GreedyComparison\\Alpha=0.8\\" + str(i) + "online" + str(5-i) + "physical" + ".pdf", bbox_inches='tight' )
   
   
        #plt.title("Online barista: " + str(i) + ", Physical barista: " + str(5-i))
    plt.show()

        
       

print(df.dtypes)
# Out:
# df_plot dataframe is below
#      onlineBarista  physicalBarista  numCustomer  alpha  noReGreedy  reGreedy  \
# 0              1.0              4.0          2.0    0.8        18.0      16.0
# 1              1.0              4.0          3.0    0.8        28.0      24.0
# 2              1.0              4.0          4.0    0.8        38.0      32.0
# 3              1.0              4.0          5.0    0.8        48.0      40.0
# 4              1.0              4.0          6.0    0.8        60.0      52.0
# ..             ...              ...          ...    ...         ...       ...
# 494            1.0              4.0        496.0    0.8    120693.2  115848.0
# 495            1.0              4.0        497.0    0.8    121171.2  116252.0
# 496            1.0              4.0        498.0    0.8    121653.6  116656.0
# 497            1.0              4.0        499.0    0.8    122136.6  117140.6
# 498            1.0              4.0        500.0    0.8    122619.6  117625.2
#
#      allQueue   allLine
# 0        16.0      20.0
# 1        24.0      30.0
# 2        32.0      40.0
# 3        40.0      50.0
# 4        52.0      65.0
# ..        ...       ...
# 494  101384.0  126730.0
# 495  101788.0  127235.0
# 496  102192.0  127740.0
# 497  102596.0  128245.0
# 498  103000.0  128750.0
#
# [499 rows x 8 columns]
# df_plot dataframe is below
#      onlineBarista  physicalBarista  numCustomer  alpha  noReGreedy  reGreedy  \
# 499            2.0              3.0          1.0    0.8         8.0       8.0
# 500            2.0              3.0          2.0    0.8        16.0      16.0
# 501            2.0              3.0          3.0    0.8        26.0      24.0
# 502            2.0              3.0          4.0    0.8        36.0      32.0
# 503            2.0              3.0          5.0    0.8        46.0      40.0
# ..             ...              ...          ...    ...         ...       ...
# 994            2.0              3.0        496.0    0.8    115206.8  112256.0
# 995            2.0              3.0        497.0    0.8    115664.8  112660.0
# 996            2.0              3.0        498.0    0.8    116123.2  113064.0
# 997            2.0              3.0        499.0    0.8    116581.6  113468.0
# 998            2.0              3.0        500.0    0.8    117044.6  113952.6
#
#      allQueue   allLine
# 499       8.0      10.0
# 500      16.0      20.0
# 501      24.0      30.0
# 502      32.0      40.0
# 503      40.0      50.0
# ..        ...       ...
# 994  101384.0  126730.0
# 995  101788.0  127235.0
# 996  102192.0  127740.0
# 997  102596.0  128245.0
# 998  103000.0  128750.0
#
# [500 rows x 8 columns]
# df_plot dataframe is below
#       onlineBarista  physicalBarista  numCustomer  alpha  noReGreedy  \
# 999             3.0              2.0          1.0    0.8         8.0
# 1000            3.0              2.0          2.0    0.8        16.0
# 1001            3.0              2.0          3.0    0.8        24.0
# 1002            3.0              2.0          4.0    0.8        34.0
# 1003            3.0              2.0          5.0    0.8        44.0
# ...             ...              ...          ...    ...         ...
# 1494            3.0              2.0        496.0    0.8    110198.6
# 1495            3.0              2.0        497.0    0.8    110635.6
# 1496            3.0              2.0        498.0    0.8    111072.6
# 1497            3.0              2.0        499.0    0.8    111514.2
# 1498            3.0              2.0        500.0    0.8    111955.8
#
#       reGreedy  allQueue   allLine
# 999        8.0       8.0      10.0
# 1000      16.0      16.0      20.0
# 1001      24.0      24.0      30.0
# 1002      32.0      32.0      40.0
# 1003      40.0      40.0      50.0
# ...        ...       ...       ...
# 1494  108647.6  101384.0  126730.0
# 1495  109051.6  101788.0  127235.0
# 1496  109455.6  102192.0  127740.0
# 1497  109859.6  102596.0  128245.0
# 1498  110263.6  103000.0  128750.0
#
# [500 rows x 8 columns]
# df_plot dataframe is below
#       onlineBarista  physicalBarista  numCustomer  alpha  noReGreedy  \
# 1499            4.0              1.0          1.0    0.8         8.0
# 1500            4.0              1.0          2.0    0.8        16.0
# 1501            4.0              1.0          3.0    0.8        24.0
# 1502            4.0              1.0          4.0    0.8        32.0
# 1503            4.0              1.0          5.0    0.8        42.0
# ...             ...              ...          ...    ...         ...
# 1994            4.0              1.0        496.0    0.8    105607.4
# 1995            4.0              1.0        497.0    0.8    106027.4
# 1996            4.0              1.0        498.0    0.8    106447.4
# 1997            4.0              1.0        499.0    0.8    106867.4
# 1998            4.0              1.0        500.0    0.8    107292.2
#
#       reGreedy  allQueue   allLine
# 1499       8.0       8.0      10.0
# 1500      16.0      16.0      20.0
# 1501      24.0      24.0      30.0
# 1502      32.0      32.0      40.0
# 1503      40.0      40.0      50.0
# ...        ...       ...       ...
# 1994  105023.4  101384.0  126730.0
# 1995  105427.4  101788.0  127235.0
# 1996  105831.4  102192.0  127740.0
# 1997  106235.4  102596.0  128245.0
# 1998  106639.4  103000.0  128750.0
#
# [500 rows x 8 columns]
# onlineBarista      float64
# physicalBarista    float64
# numCustomer        float64
# alpha              float64
# noReGreedy         float64
# reGreedy           float64
# allQueue           float64
# allLine            float64
# dtype: object
