# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("costComparison0.8.txt", sep = ",")
df = pd.DataFrame(df)
df.columns = ["onlineBarista","physicalBarista", "alpha", "numCustomer", "noReGreedy", "reGreedy", "optimalNoRe","SPNE","allQueue","allLine"]


df['allLine'] = df['allLine'].str.strip(']').astype(float)
df['onlineBarista'] = df['onlineBarista'].str.strip('[').astype(float)


pd.to_numeric(df['onlineBarista'])
pd.to_numeric(df['physicalBarista'])


for i in range(1, 5):
    df_plot = df[df['onlineBarista'] == i]
    df_plot = df_plot[df_plot['physicalBarista'] == 5-i]
    print("df_plot dataframe is below")
    print(df_plot)
       
    plt.plot(df_plot['numCustomer'], df_plot['reGreedy']/df_plot['numCustomer'], label = "Greedy with Reallocation")
    plt.plot(df_plot['numCustomer'], df_plot['noReGreedy']/df_plot['numCustomer'], label = "Greedy with no Reallocation")
    plt.plot(df_plot['numCustomer'], df_plot['optimalNoRe']/df_plot['numCustomer'],  label = "Optimal of no Reallocation")
    plt.plot(df_plot['numCustomer'], df_plot['SPNE']/df_plot['numCustomer'],  label = "SPNE with Reallocation")
    plt.plot(df_plot['numCustomer'], df_plot['allQueue']/df_plot['numCustomer'],  label = "All queue with Reallocation")
    plt.plot(df_plot['numCustomer'], df_plot['allLine']/df_plot['numCustomer'], label = "All line with Reallocation")
   
    plt.title("Num of online baristas: " + str(i) + ", Num of physical baristas:" + str(5-i))
    plt.legend(loc="upper left", fontsize = "5")
   

        #plt.title("Online barista: " + str(i) + ", Physical barista: " + str(5-i))
    plt.show()

        
       

print(df.dtypes)
# Out:
# df_plot dataframe is below
#     onlineBarista  physicalBarista  alpha  numCustomer  noReGreedy  reGreedy  \
# 0             1.0              4.0    0.8          2.0        18.0      16.0
# 1             1.0              4.0    0.8          3.0        28.0      24.0
# 2             1.0              4.0    0.8          4.0        38.0      32.0
# 3             1.0              4.0    0.8          5.0        48.0      40.0
# 4             1.0              4.0    0.8          6.0        60.0      52.0
# 5             1.0              4.0    0.8          7.0        75.0      64.0
# 6             1.0              4.0    0.8          8.0        90.0      76.0
# 7             1.0              4.0    0.8          9.0       105.0      88.0
# 8             1.0              4.0    0.8         10.0       120.0     100.0
# 9             1.0              4.0    0.8         11.0       136.0     118.2
# 10            1.0              4.0    0.8         12.0       156.0     136.4
# 11            1.0              4.0    0.8         13.0       176.0     154.6
# 12            1.0              4.0    0.8         14.0       196.0     172.8
# 13            1.0              4.0    0.8         15.0       216.0     188.8
#
#     optimalNoRe   SPNE  allQueue  allLine
# 0          18.0   16.0      16.0     20.0
# 1          28.0   24.0      24.0     30.0
# 2          38.0   32.0      32.0     40.0
# 3          48.0   40.0      40.0     50.0
# 4          60.0   52.0      52.0     65.0
# 5          74.8   64.0      64.0     80.0
# 6          89.6   76.0      76.0     95.0
# 7         104.4   88.0      88.0    110.0
# 8         119.2  102.6     100.0    125.0
# 9         135.2  128.0     116.0    145.0
# 10        154.8  144.0     132.0    165.0
# 11        174.4  160.0     148.0    185.0
# 12        194.0  176.0     164.0    205.0
# 13        213.6  192.0     180.0    225.0
# df_plot dataframe is below
#     onlineBarista  physicalBarista  alpha  numCustomer  noReGreedy  reGreedy  \
# 14            2.0              3.0    0.8          1.0         8.0       8.0
# 15            2.0              3.0    0.8          2.0        16.0      16.0
# 16            2.0              3.0    0.8          3.0        26.0      24.0
# 17            2.0              3.0    0.8          4.0        36.0      32.0
# 18            2.0              3.0    0.8          5.0        46.0      40.0
# 19            2.0              3.0    0.8          6.0        58.0      52.0
# 20            2.0              3.0    0.8          7.0        70.0      64.0
# 21            2.0              3.0    0.8          8.0        85.0      76.0
# 22            2.0              3.0    0.8          9.0       100.0      88.0
# 23            2.0              3.0    0.8         10.0       115.0     100.0
# 24            2.0              3.0    0.8         11.0       131.0     118.4
# 25            2.0              3.0    0.8         12.0       147.0     136.8
# 26            2.0              3.0    0.8         13.0       167.0     155.2
# 27            2.0              3.0    0.8         14.0       187.0     171.2
# 28            2.0              3.0    0.8         15.0       207.0     187.2
#
#     optimalNoRe   SPNE  allQueue  allLine
# 14          8.0    8.0       8.0     10.0
# 15         16.0   16.0      16.0     20.0
# 16         26.0   24.0      24.0     30.0
# 17         36.0   32.0      32.0     40.0
# 18         46.0   40.0      40.0     50.0
# 19         58.0   52.0      52.0     65.0
# 20         70.0   64.0      64.0     80.0
# 21         84.6   76.0      76.0     95.0
# 22         99.2   88.0      88.0    110.0
# 23        113.8  100.0     100.0    125.0
# 24        129.8  125.0     116.0    145.0
# 25        145.8  141.0     132.0    165.0
# 26        165.0  157.0     148.0    185.0
# 27        184.2  173.0     164.0    205.0
# 28        203.4  189.0     180.0    225.0
# df_plot dataframe is below
#     onlineBarista  physicalBarista  alpha  numCustomer  noReGreedy  reGreedy  \
# 29            3.0              2.0    0.8          1.0         8.0       8.0
# 30            3.0              2.0    0.8          2.0        16.0      16.0
# 31            3.0              2.0    0.8          3.0        24.0      24.0
# 32            3.0              2.0    0.8          4.0        34.0      32.0
# 33            3.0              2.0    0.8          5.0        44.0      40.0
# 34            3.0              2.0    0.8          6.0        56.0      52.0
# 35            3.0              2.0    0.8          7.0        68.0      64.0
# 36            3.0              2.0    0.8          8.0        80.0      76.0
# 37            3.0              2.0    0.8          9.0        95.0      88.0
# 38            3.0              2.0    0.8         10.0       110.0     100.0
# 39            3.0              2.0    0.8         11.0       126.0     118.6
# 40            3.0              2.0    0.8         12.0       142.0     137.2
# 41            3.0              2.0    0.8         13.0       158.0     153.2
# 42            3.0              2.0    0.8         14.0       178.0     169.2
# 43            3.0              2.0    0.8         15.0       198.0     185.2
#
#     optimalNoRe   SPNE  allQueue  allLine
# 29          8.0    8.0       8.0     10.0
# 30         16.0   16.0      16.0     20.0
# 31         24.0   24.0      24.0     30.0
# 32         34.0   32.0      32.0     40.0
# 33         44.0   40.0      40.0     50.0
# 34         56.0   52.0      52.0     65.0
# 35         68.0   64.0      64.0     80.0
# 36         80.0   76.0      76.0     95.0
# 37         94.4   88.0      88.0    110.0
# 38        108.8  100.0     100.0    125.0
# 39        124.8  122.0     116.0    145.0
# 40        140.8  138.0     132.0    165.0
# 41        156.8  154.0     148.0    185.0
# 42        175.8  170.0     164.0    205.0
# 43        194.8  186.0     180.0    225.0
# df_plot dataframe is below
#     onlineBarista  physicalBarista  alpha  numCustomer  noReGreedy  reGreedy  \
# 44            4.0              1.0    0.8          1.0         8.0       8.0
# 45            4.0              1.0    0.8          2.0        16.0      16.0
# 46            4.0              1.0    0.8          3.0        24.0      24.0
# 47            4.0              1.0    0.8          4.0        32.0      32.0
# 48            4.0              1.0    0.8          5.0        42.0      40.0
# 49            4.0              1.0    0.8          6.0        54.0      52.0
# 50            4.0              1.0    0.8          7.0        66.0      64.0
# 51            4.0              1.0    0.8          8.0        78.0      76.0
# 52            4.0              1.0    0.8          9.0        90.0      88.0
# 53            4.0              1.0    0.8         10.0       105.0     100.0
# 54            4.0              1.0    0.8         11.0       121.0     118.8
# 55            4.0              1.0    0.8         12.0       137.0     134.8
# 56            4.0              1.0    0.8         13.0       153.0     150.8
# 57            4.0              1.0    0.8         14.0       169.0     166.8
# 58            4.0              1.0    0.8         15.0       189.0     182.8
#
#     optimalNoRe   SPNE  allQueue  allLine
# 44          8.0    8.0       8.0     10.0
# 45         16.0   16.0      16.0     20.0
# 46         24.0   24.0      24.0     30.0
# 47         32.0   32.0      32.0     40.0
# 48         42.0   40.0      40.0     50.0
# 49         54.0   52.0      52.0     65.0
# 50         66.0   64.0      64.0     80.0
# 51         78.0   76.0      76.0     95.0
# 52         90.0   88.0      88.0    110.0
# 53        104.2  100.0     100.0    125.0
# 54        120.2  119.0     116.0    145.0
# 55        136.2  135.0     132.0    165.0
# 56        152.2  151.0     148.0    185.0
# 57        168.2  167.0     164.0    205.0
# 58        187.2  183.0     180.0    225.0
# onlineBarista      float64
# physicalBarista    float64
# alpha              float64
# numCustomer        float64
# noReGreedy         float64
# reGreedy           float64
# optimalNoRe        float64
# SPNE               float64
# allQueue           float64
# allLine            float64
# dtype: object
