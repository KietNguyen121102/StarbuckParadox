# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("costComparison0.6.txt", sep = ",")
df = pd.DataFrame(df)
df.columns = ["onlineBarista","physicalBarista", "alpha", "numCustomer", "noReGreedy", "reGreedy", "optimalNoRe","SPNE","allQueue","allLine"]


df['allLine'] = df['allLine'].str.strip(']').astype(float)
df['onlineBarista'] = df['onlineBarista'].str.strip('[').astype(float)


pd.to_numeric(df['onlineBarista'])
pd.to_numeric(df['physicalBarista'])


for i in range(1, 5):
    df_plot = df[df['onlineBarista'] == i]
    df_plot = df_plot[df_plot['physicalBarista'] == 5-i]
    print("df_plot dataframe is below")
    print(df_plot)
       
    plt.plot(df_plot['numCustomer'], df_plot['reGreedy']/df_plot['numCustomer'], label = "Greedy with Reallocation")
    plt.plot(df_plot['numCustomer'], df_plot['noReGreedy']/df_plot['numCustomer'], label = "Greedy with no Reallocation")
    plt.plot(df_plot['numCustomer'], df_plot['optimalNoRe']/df_plot['numCustomer'],  label = "Optimal of no Reallocation")
    plt.plot(df_plot['numCustomer'], df_plot['SPNE']/df_plot['numCustomer'],  label = "SPNE with Reallocation")
    plt.plot(df_plot['numCustomer'], df_plot['allQueue']/df_plot['numCustomer'],  label = "All queue with Reallocation")
    plt.plot(df_plot['numCustomer'], df_plot['allLine']/df_plot['numCustomer'], label = "All line with Reallocation")
   
    plt.title("Num of online baristas: " + str(i) + ", Num of physical baristas:" + str(5-i))
    plt.legend(loc="upper left", fontsize = "5")
   

        #plt.title("Online barista: " + str(i) + ", Physical barista: " + str(5-i))
    plt.show()

        
       

print(df.dtypes)
# Out:
# df_plot dataframe is below
#     onlineBarista  physicalBarista  alpha  numCustomer  noReGreedy  reGreedy  \
# 0             1.0              4.0    0.6          2.0        16.0      12.0
# 1             1.0              4.0    0.6          3.0        26.0      18.0
# 2             1.0              4.0    0.6          4.0        36.0      24.0
# 3             1.0              4.0    0.6          5.0        45.6      30.0
# 4             1.0              4.0    0.6          6.0        55.6      39.0
# 5             1.0              4.0    0.6          7.0        70.0      48.0
# 6             1.0              4.0    0.6          8.0        84.0      57.0
# 7             1.0              4.0    0.6          9.0        98.0      66.0
# 8             1.0              4.0    0.6         10.0       112.0      75.0
# 9             1.0              4.0    0.6         11.0       127.0      91.4
# 10            1.0              4.0    0.6         12.0       144.4     107.8
# 11            1.0              4.0    0.6         13.0       163.4     124.2
# 12            1.0              4.0    0.6         14.0       182.4     140.6
# 13            1.0              4.0    0.6         15.0       201.4     152.6
#
#     optimalNoRe   SPNE  allQueue  allLine
# 0          16.0   12.0      12.0     20.0
# 1          26.0   18.0      18.0     30.0
# 2          36.0   24.0      24.0     40.0
# 3          45.6   30.0      30.0     50.0
# 4          55.0   39.0      39.0     65.0
# 5          69.4   48.0      48.0     80.0
# 6          83.4   57.0      57.0     95.0
# 7          97.4   66.0      66.0    110.0
# 8         111.4   75.0      75.0    125.0
# 9         125.4   97.0      87.0    145.0
# 10        141.2  114.2      99.0    165.0
# 11        160.0  131.8     111.0    185.0
# 12        178.8  143.8     123.0    205.0
# 13        197.6  155.8     135.0    225.0
# df_plot dataframe is below
#     onlineBarista  physicalBarista  alpha  numCustomer  noReGreedy  reGreedy  \
# 14            2.0              3.0    0.6          1.0         6.0       6.0
# 15            2.0              3.0    0.6          2.0        12.0      12.0
# 16            2.0              3.0    0.6          3.0        22.0      18.0
# 17            2.0              3.0    0.6          4.0        32.0      24.0
# 18            2.0              3.0    0.6          5.0        41.6      30.0
# 19            2.0              3.0    0.6          6.0        51.2      39.0
# 20            2.0              3.0    0.6          7.0        61.2      48.0
# 21            2.0              3.0    0.6          8.0        75.0      57.0
# 22            2.0              3.0    0.6          9.0        88.8      66.0
# 23            2.0              3.0    0.6         10.0       101.8      75.0
# 24            2.0              3.0    0.6         11.0       114.8      91.8
# 25            2.0              3.0    0.6         12.0       129.8     108.6
# 26            2.0              3.0    0.6         13.0       146.6     125.4
# 27            2.0              3.0    0.6         14.0       163.4     137.4
# 28            2.0              3.0    0.6         15.0       181.4     149.4
#
#     optimalNoRe   SPNE  allQueue  allLine
# 14          6.0    6.0       6.0     10.0
# 15         12.0   12.0      12.0     20.0
# 16         22.0   18.0      18.0     30.0
# 17         32.0   24.0      24.0     40.0
# 18         41.6   30.0      30.0     50.0
# 19         51.0   39.0      39.0     65.0
# 20         60.0   48.0      48.0     80.0
# 21         73.8   57.0      57.0     95.0
# 22         87.4   66.0      66.0    110.0
# 23        100.6   75.0      75.0    125.0
# 24        113.6   91.8      87.0    145.0
# 25        126.6  109.0      99.0    165.0
# 26        142.2  126.2     111.0    185.0
# 27        157.8  138.2     123.0    205.0
# 28        175.6  150.2     135.0    225.0
# df_plot dataframe is below
#     onlineBarista  physicalBarista  alpha  numCustomer  noReGreedy  reGreedy  \
# 29            3.0              2.0    0.6          1.0         6.0       6.0
# 30            3.0              2.0    0.6          2.0        12.0      12.0
# 31            3.0              2.0    0.6          3.0        18.0      18.0
# 32            3.0              2.0    0.6          4.0        28.0      24.0
# 33            3.0              2.0    0.6          5.0        37.6      30.0
# 34            3.0              2.0    0.6          6.0        47.2      39.0
# 35            3.0              2.0    0.6          7.0        56.8      48.0
# 36            3.0              2.0    0.6          8.0        66.8      57.0
# 37            3.0              2.0    0.6          9.0        80.0      66.0
# 38            3.0              2.0    0.6         10.0        93.2      75.0
# 39            3.0              2.0    0.6         11.0       106.2      87.0
# 40            3.0              2.0    0.6         12.0       118.8     103.8
# 41            3.0              2.0    0.6         13.0       133.8     120.6
# 42            3.0              2.0    0.6         14.0       150.0     132.6
# 43            3.0              2.0    0.6         15.0       166.2     144.6
#
#     optimalNoRe   SPNE  allQueue  allLine
# 29          6.0    6.0       6.0     10.0
# 30         12.0   12.0      12.0     20.0
# 31         18.0   18.0      18.0     30.0
# 32         28.0   24.0      24.0     40.0
# 33         37.6   30.0      30.0     50.0
# 34         47.0   39.0      39.0     65.0
# 35         56.0   48.0      48.0     80.0
# 36         65.0   57.0      57.0     95.0
# 37         78.2   66.0      66.0    110.0
# 38         91.4   75.0      75.0    125.0
# 39        104.0   87.0      87.0    145.0
# 40        116.6  103.8      99.0    165.0
# 41        128.6  121.0     111.0    185.0
# 42        144.0  133.0     123.0    205.0
# 43        159.4  145.0     135.0    225.0
# df_plot dataframe is below
#     onlineBarista  physicalBarista  alpha  numCustomer  noReGreedy  reGreedy  \
# 44            4.0              1.0    0.6          1.0         6.0       6.0
# 45            4.0              1.0    0.6          2.0        12.0      12.0
# 46            4.0              1.0    0.6          3.0        18.0      18.0
# 47            4.0              1.0    0.6          4.0        24.0      24.0
# 48            4.0              1.0    0.6          5.0        33.6      30.0
# 49            4.0              1.0    0.6          6.0        43.2      39.0
# 50            4.0              1.0    0.6          7.0        52.8      48.0
# 51            4.0              1.0    0.6          8.0        62.4      57.0
# 52            4.0              1.0    0.6          9.0        72.4      66.0
# 53            4.0              1.0    0.6         10.0        85.0      75.0
# 54            4.0              1.0    0.6         11.0        97.6      87.0
# 55            4.0              1.0    0.6         12.0       110.2      99.0
# 56            4.0              1.0    0.6         13.0       122.8     115.8
# 57            4.0              1.0    0.6         14.0       137.8     127.8
# 58            4.0              1.0    0.6         15.0       153.4     139.8
#
#     optimalNoRe   SPNE  allQueue  allLine
# 44          6.0    6.0       6.0     10.0
# 45         12.0   12.0      12.0     20.0
# 46         18.0   18.0      18.0     30.0
# 47         24.0   24.0      24.0     40.0
# 48         33.6   30.0      30.0     50.0
# 49         43.0   39.0      39.0     65.0
# 50         52.0   48.0      48.0     80.0
# 51         61.0   57.0      57.0     95.0
# 52         70.0   66.0      66.0    110.0
# 53         82.6   75.0      75.0    125.0
# 54         95.2   87.0      87.0    145.0
# 55        107.4   99.0      99.0    165.0
# 56        119.4  115.8     111.0    185.0
# 57        131.4  127.8     123.0    205.0
# 58        146.6  139.8     135.0    225.0
# onlineBarista      float64
# physicalBarista    float64
# alpha              float64
# numCustomer        float64
# noReGreedy         float64
# reGreedy           float64
# optimalNoRe        float64
# SPNE               float64
# allQueue           float64
# allLine            float64
# dtype: object
