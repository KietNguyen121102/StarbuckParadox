# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import numpy as np


    
df = pd.read_csv("nonStrategic.txt", sep = ",")
df = pd.DataFrame(df)
df.columns = ["onlineBarista","physicalBarista", "numCustomer", "physicalPopulation", "onlinePopulation", "totalCost"]


df['totalCost'] = df['totalCost'].str.strip(']').astype(float)
df['onlineBarista'] = df['onlineBarista'].str.strip('[').astype(float)


pd.to_numeric(df['onlineBarista'])
pd.to_numeric(df['physicalBarista'])

    # df['physicalOverOnline'].round(2)
uniques = df['physicalPopulation'].unique()
print(uniques)

    # for i in range(0,6):
for value in uniques:
        for i in range(1,5):

                df_plot = df[df['onlineBarista'] == i]
                df_plot = df_plot[df_plot['physicalBarista'] == 5-i]

                df_plot = df_plot[df_plot['physicalPopulation'] == value]


                plt.plot(df_plot['numCustomer'], df_plot['totalCost']/df_plot['numCustomer'], label = 'Online Barista: ' + str(i))
                # plt.plot(plot['greedyPopulation'], plot['NoRe']/100, label = 'NoRe Online Barista: ' + str(i))

               
                plt.xlabel("Physical Population")
                plt.ylabel("Average cost")
                plt.legend(loc="upper left", fontsize = "5")
                plt.title("Physical Population = " + str(value))

                
                # plt.savefig("C:\\Users\\Kiet Nguyen\\Documents\\UofR\\SUMMER_2024\\EmpiricalResults\\NonStrategic\\WithoutReallocation\\" + "alpha=0.2" + ".pdf", bbox_inches='tight' )
                # plt.legend(plot['physicalOverOnline'])

        
        plt.show()
# Out:
# [0.  0.2 0.4 0.6 0.8 1. ]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import numpy as np


    
df = pd.read_csv("nonStrategic.txt", sep = ",")
df = pd.DataFrame(df)
df.columns = ["onlineBarista","physicalBarista", "numCustomer", "physicalPopulation", "onlinePopulation", "totalCost"]


df['totalCost'] = df['totalCost'].str.strip(']').astype(float)
df['onlineBarista'] = df['onlineBarista'].str.strip('[').astype(float)


pd.to_numeric(df['onlineBarista'])
pd.to_numeric(df['physicalBarista'])

    # df['physicalOverOnline'].round(2)
uniques = df['physicalPopulation'].unique()
print(uniques)

    # for i in range(0,6):
for i in range(1,5):

            df_plot = df[df['onlineBarista'] == i]
            df_plot = df_plot[df_plot['physicalBarista'] == 5-i]

            df_plot = df_plot[df_plot['numCustomer'] == 100]


            plt.plot(df_plot['physicalPopulation'], df_plot['totalCost']/df_plot['numCustomer'], label = 'Online Barista: ' + str(i))
            # plt.plot(plot['greedyPopulation'], plot['NoRe']/100, label = 'NoRe Online Barista: ' + str(i))

               
            plt.xlabel("Physical Population")
            plt.ylabel("Average cost")
            plt.legend(loc="upper left", fontsize = "5")

                
                # plt.savefig("C:\\Users\\Kiet Nguyen\\Documents\\UofR\\SUMMER_2024\\EmpiricalResults\\NonStrategic\\WithoutReallocation\\" + "alpha=0.2" + ".pdf", bbox_inches='tight' )
                # plt.legend(plot['physicalOverOnline'])

        
plt.show()
# Out:
# [0.  0.2 0.4 0.6 0.8 1. ]
